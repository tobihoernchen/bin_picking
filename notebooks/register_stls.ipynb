# %%
from bin_picking.objects.stl_objects import register_stl_body

# %%
register_stl_body("bin", "../bin_picking/objects/stl/deskbin.stl", recreate=True)
register_stl_body("clamp", "../bin_picking/objects/stl/clamp.stl", recreate=True)
# Out:
# [<trimesh.Trimesh(vertices.shape=(13, 3), faces.shape=(22, 3))>,
#  <trimesh.Trimesh(vertices.shape=(10, 3), faces.shape=(16, 3))>,
#  <trimesh.Trimesh(vertices.shape=(18, 3), faces.shape=(32, 3))>,
#  <trimesh.Trimesh(vertices.shape=(19, 3), faces.shape=(34, 3))>,
#  <trimesh.Trimesh(vertices.shape=(16, 3), faces.shape=(28, 3))>,
#  <trimesh.Trimesh(vertices.shape=(25, 3), faces.shape=(46, 3))>,
#  <trimesh.Trimesh(vertices.shape=(28, 3), faces.shape=(52, 3))>,
#  <trimesh.Trimesh(vertices.shape=(63, 3), faces.shape=(122, 3))>,
#  <trimesh.Trimesh(vertices.shape=(64, 3), faces.shape=(124, 3))>,
#  <trimesh.Trimesh(vertices.shape=(64, 3), faces.shape=(124, 3))>]
