# %%
from bin_picking.robots.robot import register_robot_meshes_from_menagerie

menagerie_path = "../../mujoco_menagerie/universal_robots_ur5e/"
register_robot_meshes_from_menagerie(menagerie_path, "ur5e")
menagerie_path = "../../mujoco_menagerie/universal_robots_ur10e/"
register_robot_meshes_from_menagerie(menagerie_path, "ur10e")
